# %% [markdown]
# <a href="https://colab.research.google.com/github/AleksandrSechin/Python/blob/main/Seminar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Задача №63. Решение в группах
# 1. Изобразите отношение households к population с
# помощью точечного графика
# 2. Визуализировать longitude по отношения к
# median_house_value, используя линейный график
# 3. Представить гистограмму по housing_median_age
# 4. Изобразить гистограмму по median_house_value с
# оттенком housing_median_age

# %%
df = pd.read_csv ('/content/sample_data/california_housing_test.csv')
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
plt.figure(figsize= (12, 8))
sns.scatterplot(df, x = 'households', y = 'population')
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
sns.relplot(df, x = 'longitude', y = 'median_house_value', kind = 'line', aspect = 3);

# %%
sns.set(rc = {'figure.figsize': (12, 8) })
sns.relplot(df, x = 'longitude', y = 'median_house_value', kind = 'line')

# %% [markdown]
# Представить гистограмму по housing_median_age

# %%
sns.histplot(df, x = 'housing_median_age', bins =50)
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %% [markdown]
# Изобразить гистограмму по median_house_value с оттенком housing_median_age

# %%
plt.figure(figsize= (16, 8))
sns.histplot(data=df, x = 'median_house_value', hue = 'housing_median_age', palette="husl")
# Out:
# <Axes: xlabel='median_house_value', ylabel='Count'>

# %% [markdown]
# # Задача 65
# ## Написать EDA для датасета про пингвинов
# Необходимо:
# 1. Использовать 2-3 точечных графика
# 2. Применить доп измерение в точечных графиках, используя аргументы hue, size, style
# 3. Использовать PairGrid с типом графика на ваш выбор
# 4. Изобразить Heatmap
# 5. Использовать 2-3 гистограммы
#
# Чтобы подключить датасет с     пингвинами, воспользуйтесь данным скриптом:
# penguins = sns.load_dataset("penguins")
# penguins.head()

# %%
penguins = sns.load_dataset("penguins")
penguins.sample(15)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 217  Chinstrap      Dream            49.6           18.2              193.0
# 110     Adelie     Biscoe            38.1           16.5              198.0
# 72      Adelie  Torgersen            39.6           17.2              196.0
# 229     Gentoo     Biscoe            46.8           15.4              215.0
# 184  Chinstrap      Dream            42.5           16.7              187.0
# 51      Adelie     Biscoe            40.1           18.9              188.0
# 125     Adelie  Torgersen            40.6           19.0              199.0
# 209  Chinstrap      Dream            49.3           19.9              203.0
# 22      Adelie     Biscoe            35.9           19.2              189.0
# 334     Gentoo     Biscoe            46.2           14.1              217.0
# 322     Gentoo     Biscoe            47.2           15.5              215.0
# ...

# %%
sns.scatterplot(penguins, x = 'bill_length_mm', y = 'bill_depth_mm', hue = 'species', style = 'sex', size = 'island');

# %%
sns.scatterplot(penguins, x = 'flipper_length_mm', y = 'body_mass_g', hue = 'species', style = 'sex', size = 'island');

# %%
sns.scatterplot(penguins, x = 'flipper_length_mm', y = 'body_mass_g', hue = 'species', style = 'sex', size = 'flipper_length_mm');

# %% [markdown]
# Использовать PairGrid с типом графика на ваш выбор

# %%
g = sns.PairGrid(penguins[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']])
g.map(sns.scatterplot);

# %% [markdown]
# Изобразить Heatmap

# %%
corr_penguins = penguins[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']].corr().round(2)  #отбирает числовые значения и округляет до 2 знаков после запятой
corr_penguins
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm               1.00          -0.24               0.66
# bill_depth_mm               -0.24           1.00              -0.58
# flipper_length_mm            0.66          -0.58               1.00
# body_mass_g                  0.60          -0.47               0.87
#
#                    body_mass_g
# bill_length_mm            0.60
# bill_depth_mm            -0.47
# flipper_length_mm         0.87
# body_mass_g               1.00

# %%
sns.heatmap(corr_penguins, annot = True, cmap= 'coolwarm', linewidths= 1);

# %% [markdown]
# Использовать 2-3 гистограммы

# %%
sns.histplot(penguins, x = 'body_mass_g', bins =50);

# %%
sns.histplot(penguins, x = 'flipper_length_mm', bins =30);

# %%
sns.histplot(penguins, x = 'bill_length_mm', bins =30);

# %% [markdown]
# # Задача 67
# Создать новый столбец в таблице с пингвинами, который будет отвечать за показатель длины клюва пингвина.
#
# high - длинный(от 42)
#
# middle - средний(от 35 до 42)
#
# low - маленький(до 35)

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.loc[penguins['bill_length_mm'] >= 42, 'height_group'] = 'high'
penguins.loc[(penguins['bill_length_mm'] >= 35) & (penguins['bill_length_mm'] < 42), 'height_group'] = 'middle'
penguins.loc[penguins['bill_length_mm'] < 35, 'height_group'] = 'low'
penguins.sample(20)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 51      Adelie     Biscoe            40.1           18.9              188.0
# 131     Adelie  Torgersen            43.1           19.2              197.0
# 58      Adelie     Biscoe            36.5           16.6              181.0
# 16      Adelie  Torgersen            38.7           19.0              195.0
# 138     Adelie      Dream            37.0           16.5              185.0
# 190  Chinstrap      Dream            46.9           16.6              192.0
# 21      Adelie     Biscoe            37.7           18.7              180.0
# 134     Adelie      Dream            38.1           17.6              187.0
# 255     Gentoo     Biscoe            48.4           16.3              220.0
# 49      Adelie      Dream            42.3           21.2              191.0
# 161  Chinstrap      Dream            51.3           19.9              198.0
# ...

# %% [markdown]
# Задача №69. Решение в группах
# 1. Изобразить гистограмму по flipper_length_mm
# с оттенком height_group. Сделать анализ

# %%
plt.figure(figsize=(16, 10))
sns.histplot(penguins, x= 'flipper_length_mm', hue = 'height_group', bins = 20) # bins кол-во столбцов
plt.xticks(range(170, 240, 2))
plt.yticks(range(0, 27))
plt.grid(); # grid - сетка

# %%
plt.figure(figsize=(16, 6))
sns.histplot(penguins, x= 'flipper_length_mm', hue = 'height_group', bins = 30)
plt.title('Длина крыла и размеры клювов')
plt.xlabel('Длина крыла')
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %%
plt.figure(figsize=(16, 10))
sns.displot(penguins, x= 'flipper_length_mm', hue = 'height_group', bins = 20)
